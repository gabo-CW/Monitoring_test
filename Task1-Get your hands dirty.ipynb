# %% [markdown]
# <a href="https://colab.research.google.com/github/gabo-CW/Monitoring_test/blob/main/Task1-Get%20your%20hands%20dirty.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import sqlite3
import matplotlib.pyplot as plt

# %%
conn = sqlite3.connect('case1_transactions.db')

# %%
df1 = pd.read_csv('checkout_1.csv')
df2 = pd.read_csv('checkout_2.csv')

# %%
df1.to_sql('tabela1', conn, if_exists='replace', index=False)
df2.to_sql('tabela2', conn, if_exists='replace', index=False)
# Out:
# 24

# %%
conn = sqlite3.connect('case1_transactions.db')

# %%
query = "SELECT * FROM tabela1"
query2 = "SELECT * FROM tabela2"

# %%
df_resultado = pd.read_sql_query(query, conn)
df_resultado2 = pd.read_sql_query(query2, conn)

# %%
print(df_resultado)
print("----------------------------------------------------------------------------")
print(df_resultado2)

# %%
plt.plot(df1['time'],df1['today'], label='Today', marker='o')
plt.plot(df1['time'],df1['yesterday'], label='Yesterday', marker='o')
plt.plot(df1['time'],df1['avg_last_week'], label='Avg last week', marker='o')
plt.plot(df1['time'],df1['avg_last_month'], label='Avg last month', marker='o')
plt.title('Hoje x médias de última semana e mês (checkout01)')
plt.xlabel('Tempo')
plt.ylabel('Vendas')
plt.legend()
plt.tight_layout()

# %%
plt.plot(df2['time'],df2['today'], label='Today', marker='o')
plt.plot(df1['time'],df1['yesterday'], label='Yesterday', marker='o')
plt.plot(df2['time'],df2['avg_last_week'], label='Avg last week', marker='o')
plt.plot(df2['time'],df2['avg_last_month'], label='Avg last month', marker='o')
plt.title('Hoje x médias de última semana e mês (checkout02)')
plt.xlabel('Tempo')
plt.ylabel('Vendas')
plt.legend()
plt.tight_layout()

# %%
conn.close()
